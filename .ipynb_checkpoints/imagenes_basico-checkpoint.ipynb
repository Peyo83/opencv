# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pwd
# Out:
# '/home/jovyan/work'

# %%
imagen = Image.open('imagenes/minion.jpg')

# %%
imagen
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=630x354 at 0x7FA855BEAA58>

# %%
type(imagen)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
imagen.size
# Out:
# (630, 354)

# %%
array_imagen = np.asarray(imagen)

# %%
array_imagen
# Out:
# array([[[  3,  25,  46],
#         [  3,  25,  46],
#         [  3,  25,  46],
#         ...,
#         [ 44,  95, 142],
#         [ 44,  95, 142],
#         [ 44,  95, 142]],
#
#        [[  3,  25,  46],
#         [  3,  25,  46],
#         [  3,  25,  46],
#         ...,
#         [ 44,  95, 142],
#         [ 44,  95, 142],
#         [ 44,  95, 142]],
#
#        [[  3,  25,  48],
#         [  3,  25,  48],
#         [  3,  25,  48],
#         ...,
#         [ 46,  94, 140],
#         [ 46,  94, 140],
#         [ 46,  94, 140]],
#
#        ...,
#
#        [[ 67,  78, 108],
#         [ 67,  78, 108],
#         [ 67,  78, 108],
#         ...,
#         [115, 149, 186],
#         [116, 150, 187],
#         [117, 151, 188]],
#
#        [[ 71,  78, 104],
#         [ 70,  77, 103],
#         [ 69,  76, 102],
#         ...,
#         [113, 147, 182],
#         [115, 149, 184],
#         [116, 150, 185]],
#
#        [[ 71,  78, 104],
#         [ 70,  77, 103],
#         [ 69,  76, 102],
# ...

# %%
plt.imshow(array_imagen)

# %%
array_imagen.shape # El 3 indica 3 dimensiones de color (RGB)
# Out:
# (354, 630, 3)

# %%
array_imagen[:,:,0] # color rojo
# Out:
# array([[  3,   3,   3, ...,  44,  44,  44],
#        [  3,   3,   3, ...,  44,  44,  44],
#        [  3,   3,   3, ...,  46,  46,  46],
#        ...,
#        [ 67,  67,  67, ..., 115, 116, 117],
#        [ 71,  70,  69, ..., 113, 115, 116],
#        [ 71,  70,  69, ..., 113, 115, 116]], dtype=uint8)

# %%
array_imagen[:,:,1] # color verde
# Out:
# array([[ 25,  25,  25, ...,  95,  95,  95],
#        [ 25,  25,  25, ...,  95,  95,  95],
#        [ 25,  25,  25, ...,  94,  94,  94],
#        ...,
#        [ 78,  78,  78, ..., 149, 150, 151],
#        [ 78,  77,  76, ..., 147, 149, 150],
#        [ 78,  77,  76, ..., 147, 149, 150]], dtype=uint8)

# %%
array_imagen[:,:,2] # color azul
# Out:
# array([[ 46,  46,  46, ..., 142, 142, 142],
#        [ 46,  46,  46, ..., 142, 142, 142],
#        [ 48,  48,  48, ..., 140, 140, 140],
#        ...,
#        [108, 108, 108, ..., 186, 187, 188],
#        [104, 103, 102, ..., 182, 184, 185],
#        [104, 103, 102, ..., 182, 184, 185]], dtype=uint8)

# %%
plt.imshow(array_imagen[:,:,0])

# %%
plt.imshow(array_imagen[:,:,1])

# %%
plt.imshow(array_imagen[:,:,2])
