# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/home/jovyan/work'

# %%
imagen = cv2.imread('imagenes/minion.jpg')

# %%
type(imagen)
# Out:
# numpy.ndarray

# %%
imagen.shape
# Out:
# (354, 630, 3)

# %%
plt.imshow(imagen)

# %%
# OpenCV --> BGR
# Matplotlib --> RGB

# %%
imagen = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imagen)

# %%
imagen_bn = cv2.imread('imagenes/minion.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(imagen_bn, cmap='gray')
